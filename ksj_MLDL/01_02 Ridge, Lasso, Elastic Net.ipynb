# %% [markdown]
# # 2. Ridge Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge
# Ridge모델은 linear_model에서 Ridge로 불러올 수 있습니다.

# %%
X_multi, y_multi = make_regression(n_samples = 1000, n_features = 30, bias = 10, noise = 50)
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size = 0.3, shuffle = True)

# %%
model_Ridge = Ridge(alpha=10).fit(X_train, y_train)

# %%
Ridge?

# %%
print('weight : \n{}\n\n'.format(model_Ridge.coef_))
print('bias : \n{}'.format(model_Ridge.intercept_))
# Out:
# weight :
# [  1.63343203  -1.35562621  -0.88220097  -2.56429278   2.90580037
#   46.64444732  39.97847813   2.17145643  86.44468619   1.50596424
#   -0.20655247  -0.86283898  32.81646902  97.98891832  68.48530795
#    1.42026176  19.41680154  -1.13283709   0.20306603   9.40064752
#   -1.67497901  -2.80334996 102.13430278   0.20367855  -0.20363211
#    1.67658642   2.87914928   0.70350057  -3.39522502  71.5908752 ]
#
#
# bias :
# 11.077927251353

# %%
from sklearn.linear_model import LinearRegression
model_Linear = LinearRegression().fit(X_train, y_train)
model_Linear.coef_
# Out:
# array([ 1.59332461e+00, -1.31687892e+00, -9.32120060e-01, -2.69349956e+00,
#         2.98215857e+00,  4.74265323e+01,  4.06360489e+01,  2.12850369e+00,
#         8.78588113e+01,  1.70513447e+00, -2.38412400e-01, -7.17768901e-01,
#         3.31630268e+01,  9.92801494e+01,  6.94902749e+01,  1.16483041e+00,
#         1.97581898e+01, -8.85651377e-01,  6.46078714e-02,  9.59474967e+00,
#        -1.57001350e+00, -2.94487908e+00,  1.03574885e+02,  1.74838918e-01,
#        -2.64465268e-01,  1.73530747e+00,  3.21204215e+00,  5.03451452e-01,
#        -3.31107517e+00,  7.27734429e+01])

# %% [markdown]
# weight를 살펴보면 0에 가깝게 변한 값들을 볼 수 있다.

# %%
print('train score : {:.2f}'.format(model_Ridge.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_Ridge.score(X_test, y_test)))
# Out:
# train score : 0.95
# test score : 0.94

# %% [markdown]
# Ridge는 alpha라는 파라미터를 가지고 있다. 기본값은 1.0
# 최적의 alpha값은 정해진 것이 없고 데이터셋마다 다르다.

# %%
model_ridge500 = Ridge(alpha = 500).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ridge500.coef_))
print('bias : \n{}'.format(model_ridge500.intercept_))
# Out:
# weight :
# [ 2.11109349 -1.68724169  0.21888916  0.06580182  1.42553724 25.83103851
#  22.28591848  2.43097315 48.8563104  -1.88436472  0.30850361 -3.08717171
#  21.41916282 60.3421763  40.50853041  5.20988516 10.21121139 -4.7670137
#   2.46428079  4.51564738 -3.1087007  -0.11468317 61.3607876   0.54245231
#   1.03500807  0.67069166 -3.15208051  3.73161568 -4.07310281 40.20984989]
#
#
# bias :
# 10.438603833529282

# %%
print('train score : {:.2f}'.format(model_ridge500.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_ridge500.score(X_test, y_test)))
# Out:
# train score : 0.79
# test score : 0.77

# %% [markdown]
# alpha값을 높이면 0에 가깝게 만들어 훈련 셋의 성능은 나빠지지만 일반화에 도움을 준다.

# %%
model_ridge005 = Ridge(alpha = 0.005).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ridge005.coef_))
print('bias : \n{}'.format(model_ridge005.intercept_))
# Out:
# weight :
# [ 1.59334534e+00 -1.31689910e+00 -9.32094593e-01 -2.69343340e+00
#   2.98211927e+00  4.74261346e+01  4.06357147e+01  2.12852613e+00
#   8.78580921e+01  1.70503199e+00 -2.38395968e-01 -7.17843688e-01
#   3.31628519e+01  9.92794948e+01  6.94897646e+01  1.16496224e+00
#   1.97580164e+01 -8.85779001e-01  6.46791430e-02  9.59465085e+00
#  -1.57006773e+00 -2.94480641e+00  1.03574153e+02  1.74853915e-01
#  -2.64434190e-01  1.73527717e+00  3.21187118e+00  5.03554664e-01
#  -3.31111898e+00  7.27728414e+01]
#
#
# bias :
# 11.122479992104985

# %%
print('train score : {:.2f}'.format(model_ridge005.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_ridge005.score(X_test, y_test)))
# Out:
# train score : 0.95
# test score : 0.95

# %% [markdown]
# 반대로 alpha값을 낮추게 되면 제한을 하지 않으므로 선형회귀와 비슷해진다.

# %%
# 선형회귀와 비교
from sklearn.linear_model import LinearRegression
hypothesis_multi = LinearRegression()
model_linear_multi = hypothesis_multi.fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_linear_multi.coef_))
print('bias : \n{}'.format(model_linear_multi.intercept_))
# Out:
# weight :
# [ 1.59332461e+00 -1.31687892e+00 -9.32120060e-01 -2.69349956e+00
#   2.98215857e+00  4.74265323e+01  4.06360489e+01  2.12850369e+00
#   8.78588113e+01  1.70513447e+00 -2.38412400e-01 -7.17768901e-01
#   3.31630268e+01  9.92801494e+01  6.94902749e+01  1.16483041e+00
#   1.97581898e+01 -8.85651377e-01  6.46078714e-02  9.59474967e+00
#  -1.57001350e+00 -2.94487908e+00  1.03574885e+02  1.74838918e-01
#  -2.64465268e-01  1.73530747e+00  3.21204215e+00  5.03451452e-01
#  -3.31107517e+00  7.27734429e+01]
#
#
# bias :
# 11.122502997384391

# %%
print('학습 데이터 점수 : {:.2f}'.format(model_linear_multi.score(X_train, y_train)))
print('검증 데이터 점수 : {:.2f}'.format(model_linear_multi.score(X_test, y_test)))
# Out:
# 학습 데이터 점수 : 0.95
# 검증 데이터 점수 : 0.95

# %% [markdown]
# # 3. Lasso Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.linear_model import Lasso
import numpy as np
# Lasso모델은 linear_model에서 Lasso로 불러올 수 있습니다.

# %%
model_lasso = Lasso(alpha=10).fit(X_train, y_train)

# %%
print('weight : \n{}\n\n'.format(model_lasso.coef_))
print('bias : \n{}'.format(model_lasso.intercept_))
# Out:
# weight :
# [ 0.         -0.         -0.         -0.          0.         35.74282603
#  30.1735254   0.         76.9906731  -0.         -0.         -0.
#  24.46026465 91.42738772 58.93970061  0.          8.27704064 -0.
#   0.          0.         -0.         -0.         92.94079291 -0.
#   0.          0.          0.          0.         -0.         61.90557803]
#
#
# bias :
# 10.62572658464125

# %% [markdown]
# Lasso의 weight를 살펴보면 Ridge와는 다르게 0으로 가까워지다 못해 0이 되어버린 값들을 살펴볼 수 있다.
# lasso에서 alpha의 기본값은 1.0으로 설정되어있다.

# %%
print('사용된 특성 수 : {}개'.format(np.sum(model_lasso.coef_ != 0)))
# 100개의 특성중 몇개의 특성을 사용했는지 확인해볼 수 있다.
# Out:
# 사용된 특성 수 : 9개

# %%
print('train score : {:.2f}'.format(model_lasso.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_lasso.score(X_test, y_test)))
# Out:
# train score : 0.93
# test score : 0.92

# %%
model_lasso005 = Lasso(alpha = 0.05, max_iter = 100000).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_lasso005.coef_))
print('bias : \n{}'.format(model_lasso005.intercept_))
# Out:
# weight :
# [ 1.53569964e+00 -1.25472943e+00 -8.91804015e-01 -2.62907607e+00
#   2.94300101e+00  4.73579349e+01  4.05733977e+01  2.07535696e+00
#   8.78193772e+01  1.64885018e+00 -1.88779569e-01 -6.68286287e-01
#   3.31226542e+01  9.92447673e+01  6.94495202e+01  1.10859590e+00
#   1.96877530e+01 -8.46265345e-01  1.15455544e-02  9.53319020e+00
#  -1.50168241e+00 -2.88825854e+00  1.03528175e+02  1.07286510e-01
#  -2.03627948e-01  1.68770300e+00  3.13855613e+00  4.61215848e-01
#  -3.25601290e+00  7.27131272e+01]
#
#
# bias :
# 11.121965903565421

# %% [markdown]
# - alpha를 줄이게 되면 가장 낮은 오차를 찾아가는 반복횟수가 늘어야 한다. 그러므로 max_iter라는 파라미터를 증가시켜주면 된다.

# %%
print('train score : {:.2f}'.format(model_lasso005.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_lasso005.score(X_test, y_test)))
# Out:
# train score : 0.95
# test score : 0.95

# %%
print('사용된 특성 수 : {}개'.format(np.sum(model_lasso005.coef_ != 0)))
# Out:
# 사용된 특성 수 : 30개

# %%
model_lasso50 = Lasso(alpha = 50, max_iter = 1000).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_lasso50.coef_))
print('bias : \n{}'.format(model_lasso50.intercept_))
# Out:
# weight :
# [ 0.         -0.         -0.          0.          0.          0.
#   0.          0.         33.323025   -0.         -0.         -0.
#   0.         59.64901126 17.67399663  0.          0.         -0.
#   0.          0.         -0.          0.         55.38562695  0.
#   0.          0.         -0.          0.         -0.         17.32717839]
#
#
# bias :
# 9.047881165008421

# %%
print('사용된 특성 수 : {}개'.format(np.sum(model_lasso50.coef_ != 0)))
# Out:
# 사용된 특성 수 : 5개

# %%
print('train score : {:.2f}'.format(model_lasso50.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_lasso50.score(X_test, y_test)))
# Out:
# train score : 0.58
# test score : 0.55

# %% [markdown]
# - train, test 둘 다 점수가 좋지 않은것을 확인할 수 있다. underfiting되었다고 볼 수 있다.

# %% [markdown]
# # 4. Elastic Net

# %% [markdown]
# - Elastic Net은 Ridge와 Lasso를 절충한 모델이다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.linear_model import ElasticNet

# %%
model_ela = ElasticNet().fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : \n{}'.format(model_ela.intercept_))
# Out:
# weight :
# [ 1.78417003 -1.42946603  0.         -0.          1.36247982 29.52092636
#  25.41607478  2.12811602 55.98718172 -1.23956938  0.         -2.60894451
#  23.67157904 68.09917083 45.96685709  4.65937775 11.5827817  -4.25594804
#   1.89275536  5.07809671 -2.66575453 -0.11242239 69.52223225  0.14133406
#   0.58376417  0.47597431 -2.20961956  3.16451763 -3.818156   46.04503774]
#
#
# bias :
# 10.486785905467777

# %%
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# 사용된 특성 수 : 27개

# %%
print('train score : {:.2f}'.format(model_ela.score(X_train, y_train)))
print('test score : {:.2f}'.format(model_ela.score(X_test, y_test)))
# Out:
# train score : 0.84
# test score : 0.83

# %%
model_ela = ElasticNet(alpha = 0.1, l1_ratio = 0.1).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : {}\n\n'.format(model_ela.intercept_))
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# weight :
# [ 1.79677133e+00 -1.50421415e+00 -6.41489615e-01 -1.95927992e+00
#   2.55736059e+00  4.28848508e+01  3.68093027e+01  2.33427492e+00
#   7.96734462e+01  6.09204003e-01 -5.82429179e-02 -1.49309518e+00
#   3.10713843e+01  9.16888232e+01  6.36250588e+01  2.52655070e+00
#   1.77592580e+01 -2.20293545e+00  8.07248568e-01  8.46815200e+00
#  -2.11855062e+00 -2.15427002e+00  9.51476964e+01  3.12027221e-01
#   7.11829166e-02  1.41042288e+00  1.36674276e+00  1.57130457e+00
#  -3.73147941e+00  6.59247807e+01]
#
#
# bias : 10.883259333161416
#
#
# 사용된 특성 수 : 30개

# %% [markdown]
# - alpha = l1(lasso) + l2(ridge)
# - l1_ratio = 0 이면 ridge 1 이면 lasso, lasso의 비율을 정해준다.

# %%
model_ela = ElasticNet(alpha = 30, l1_ratio = 0.9).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : {}\n\n'.format(model_ela.intercept_))
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# weight :
# [ 0.         -0.          0.          0.          0.          3.54327148
#   2.16661922  0.         13.84678124 -0.          0.         -0.
#   3.29177208 20.98125302 10.97043801  0.          0.         -0.
#   0.          0.         -0.          0.         20.56433412  0.
#   0.          0.         -0.          0.         -0.          9.98675898]
#
#
# bias : 11.03469356393651
#
#
# 사용된 특성 수 : 8개

# %%
model_ela = ElasticNet(alpha = 30, l1_ratio = 0.1).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : {}\n\n'.format(model_ela.intercept_))
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# weight :
# [ 0.14382858 -0.06660681  0.          0.04505147  0.00645956  1.34977526
#   1.1456162   0.13246922  2.80215206 -0.20988553  0.         -0.30563767
#   1.37257595  3.9023491   2.46158034  0.56686913  0.36454076 -0.50115767
#   0.24901035  0.06487077 -0.27065967  0.          3.85537315  0.
#   0.09728837  0.         -0.5136508   0.3854633  -0.29702354  2.25537272]
#
#
# bias : 11.456618252050587
#
#
# 사용된 특성 수 : 25개

# %%
model_ela = ElasticNet(alpha = 1, l1_ratio = 0.9).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : {}\n\n'.format(model_ela.intercept_))
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# weight :
# [ 9.53510604e-01 -6.16715968e-01 -0.00000000e+00 -8.91275540e-01
#   1.86220321e+00  4.13684748e+01  3.54225315e+01  1.48793543e+00
#   7.81701084e+01  0.00000000e+00 -0.00000000e+00 -8.53103721e-01
#   3.02025011e+01  9.03723245e+01  6.23178530e+01  1.78764748e+00
#   1.65036209e+01 -1.70084192e+00  1.24309885e-02  7.43516046e+00
#  -1.13966732e+00 -1.18463292e+00  9.35682300e+01  0.00000000e+00
#   0.00000000e+00  6.10745745e-01  2.00088087e-02  9.40087435e-01
#  -2.84724431e+00  6.43642158e+01]
#
#
# bias : 10.76035569199051
#
#
# 사용된 특성 수 : 25개

# %%
model_ela = ElasticNet(alpha = 10, l1_ratio = 0.1).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : {}\n\n'.format(model_ela.intercept_))
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# weight :
# [ 0.55644812 -0.36305164  0.14984585  0.27366591  0.20132643  4.01760332
#   3.44575758  0.53964563  8.05774865 -0.72650162  0.03086473 -0.97776196
#   3.98624781 11.00151052  7.04750396  1.66767958  1.27971318 -1.49924034
#   0.82565869  0.42020139 -0.89161948  0.14125536 10.90347598  0.0583134
#   0.41686379  0.07102058 -1.49020526  1.19102295 -0.98218969  6.53595631]
#
#
# bias : 11.22803303139273
#
#
# 사용된 특성 수 : 30개

# %%
model_ela = ElasticNet(alpha = 10, l1_ratio = 0.9).fit(X_train, y_train)
print('weight : \n{}\n\n'.format(model_ela.coef_))
print('bias : {}\n\n'.format(model_ela.intercept_))
print('사용된 특성 수 : {}개'.format(np.sum(model_ela.coef_ != 0)))
# Out:
# weight :
# [ 0.         -0.          0.          0.          0.         17.05901283
#  14.2822351   0.         37.49994454 -0.          0.         -0.
#  14.45192744 48.99557437 30.61067867  0.86842317  3.41964243 -0.67312577
#   0.          0.         -0.          0.         48.81464684  0.
#   0.          0.         -0.          0.         -0.         29.81461648]
#
#
# bias : 10.998040274362117
#
#
# 사용된 특성 수 : 11개

# %% [markdown]
# #### 보스턴 주택데이터 예측하기

# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston

# %%
boston_data = load_boston()

# %%
X_data, y_data = boston_data['data'], boston_data['target']

# %%
Ridge?

# %%
model_linear = LinearRegression()
model_ridge = Ridge(alpha=100)
model_lasso = Lasso(alpha=100)
model_elastic = ElasticNet(alpha=100, l1_ratio=0)

# %%
model_linear.fit(X_data, y_data)

# %%
model_ridge.fit(X_data, y_data) #alpha = 규제항의 파라미터

# %%
model_lasso.fit(X_data, y_data)

# %%
model_elastic.fit(X_data, y_data)

# %%
model_linear.coef_, model_linear.intercept_
np.sum(np.square(model_linear.coef_))

# %%
model_ridge.coef_, model_ridge.intercept_
np.sum(np.square(model_ridge.coef_))

# %%
model_lasso.coef_, model_lasso.intercept_

# %%
model_elastic.coef_, model_elastic.intercept_
